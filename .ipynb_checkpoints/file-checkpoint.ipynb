# %%
from bs4 import BeautifulSoup as bs
import requests
import browser_cookie3
import urllib.request
import re
import pandas as pd
import sqlite3
import http.cookiejar
import sys
import numpy as np
import seaborn as sns
import html5lib
import matplotlib.pyplot as plt

# %%
cj = browser_cookie3.firefox(domain_name='stathead.com')

# %%
def ping_url(url):
    resp = requests.get(url, cookies=cj)
    return pd.read_html(resp.content)[0]

def retrieve_gamelog(year):
    url1 = 'https://stathead.com/football/player-game-finder.cgi?request=1&order_by=age_on_day&year_min='+ str(year) + '&year_max=' + str(year) +'&season_positions%5B%5D=qb&is_starter=Y&team_success_opp=win_loss_pct&win_pct_comp_opp=gt&win_pct_val_opp=.501'
    url2 = 'https://stathead.com/football/player-game-finder.cgi?request=1&order_by=age_on_day&year_min='+ str(year) + '&year_max=' + str(year) +'&season_positions%5B%5D=qb&is_starter=Y&team_success_opp=win_loss_pct&win_pct_comp_opp=gt&win_pct_val_opp=.501&offset=200'
    urls = [url1, url2]
    check_no = 1
    error_check = 0
    
    for u in urls:
        if check_no == 1:
            df1 = pd.DataFrame(ping_url(url1))
            check_no += 1
        elif check_no == 2:
            try:
                df2 = pd.DataFrame(ping_url(url2))
            except:
                error_check = 1
        else:
            return "Formula Error"
        
    if error_check == 1:
        return df1
    else:
        return pd.concat([df1, df2])[['Player','G#','Date','Team','Opp','Result']].reset_index(drop=True).sort_values(by='Player')

# %%
def return_years(startyear, endyear):
    df_list = []
    for y in range(startyear, endyear):
        df_list.append(retrieve_gamelog(y))
    return df_list

# %%
retrieve_gamelog(1982)
# Out:
#       Rk        Player  Day  G#  Week        Date     Age Team Unnamed: 8  \
# 0      1  Craig Morton  Sun   1     1  1982-09-12  39-219  DEN        NaN
# 1      2   Ken Stabler  Sun   9    17  1983-01-02  37-008  NOR        NaN
# 2      3   Ken Stabler  Sun   7    15  1982-12-19  36-359  NOR          @
# 3      4   Ken Stabler  Sun   6    14  1982-12-12  36-352  NOR          @
# 4      5   Ken Stabler  Sun   5    13  1982-12-05  36-345  NOR        NaN
# ..   ...           ...  ...  ..   ...         ...     ...  ...        ...
# 121  122    Mike Pagel  Sun   6    14  1982-12-12  22-090  BAL          @
# 122  123    Mike Pagel  Sun   5    13  1982-12-05  22-083  BAL        NaN
# 123  124    Mike Pagel  Sun   3    11  1982-11-21  22-069  BAL          @
# 124  125    Mike Pagel  Sun   2     2  1982-09-19  22-006  BAL          @
# 125  126    Mike Pagel  Sun   1     1  1982-09-12  21-364  BAL        NaN
#
#      Opp   Result Pos.
# 0    SDG   L 3-23   QB
# 1    ATL   W 35-6   QB
# 2    DAL   L 7-21   QB
# 3    ATL   L 0-35   QB
# 4    TAM  L 10-13   QB
# ..   ...      ...  ...
# 121  MIN  L 10-13   QB
# 122  CIN  L 17-20   QB
# 123  NYJ   L 0-37   QB
# 124  MIA  L 20-24   QB
# 125  NWE  L 13-24   QB
#
# [126 rows x 12 columns]

# %%
thru_1980 = return_years(1966,1980)

# %%
thru_1980_df = pd.concat(thru_1980)[['Player','G#','Date','Team','Opp','Result']].reset_index(drop=True).sort_values(by='Player')

# %%
thru_1980_df
# Out:
#                Player  G#        Date Team  Opp   Result
# 1232       Al Woodall   8  1973-11-04  NYJ  MIA  L 14-24
# 1236       Al Woodall   4  1973-10-07  NYJ  MIA   L 3-31
# 1231       Al Woodall  10  1973-11-18  NYJ  CIN  L 14-20
# 783        Al Woodall  14  1970-12-19  NYJ  BAL  L 20-35
# 784        Al Woodall  13  1970-12-13  NYJ  MIA  L 10-16
# ...               ...  ..         ...  ...  ...      ...
# 1251      Wayne Clark   9  1973-11-11  SDG  DEN  L 19-30
# 1250      Wayne Clark  11  1973-11-25  SDG  OAK   L 3-31
# 322   Zeke Bratkowski  13  1968-12-07  GNB  BAL   L 3-16
# 323   Zeke Bratkowski   5  1968-10-13  GNB  RAM  L 14-16
# 17    Zeke Bratkowski  14  1966-12-18  GNB  RAM  W 27-23
#
# [2466 rows x 6 columns]

# %%
total_gamelog = pd.concat([thru_1980_df, gamelog1981,gamelog1982,gamelog1983,gamelog1984,gamelog1985,gamelog1986,gamelog1987,gamelog1988,gamelog1989,gamelog1990,gamelog1991,gamelog1992,gamelog1993,gamelog1994,gamelog1995,gamelog1996,gamelog1997,gamelog1998,gamelog1999,gamelog2000,gamelog2001,gamelog2002,gamelog2003,gamelog2004,gamelog2005,gamelog2006,gamelog2007,gamelog2008,gamelog2009,gamelog2010,gamelog2011,gamelog2012,gamelog2013,gamelog2014,gamelog2015,gamelog2016,gamelog2017,gamelog2018,gamelog2019,gamelog2020,gamelog2021,gamelog2022,gamelog2023])[['Player','G#','Date','Team','Opp','Result']].sort_values(by='Player').reset_index(drop=True)

# %%
total_gamelog.head(100)
# Out:
#            Player  G#        Date Team  Opp   Result
# 0     A.J. Feeley  12  2011-12-04  STL  SFO   L 0-26
# 1     A.J. Feeley  14  2004-12-20  MIA  NWE  W 29-28
# 2     A.J. Feeley  13  2004-12-12  MIA  DEN  L 17-20
# 3     A.J. Feeley  12  2004-12-05  MIA  BUF  L 32-42
# 4     A.J. Feeley  10  2004-11-21  MIA  SEA  L 17-24
# ..            ...  ..         ...  ...  ...      ...
# 95  Aaron Rodgers  12  2016-12-04  GNB  HOU  W 21-13
# 96  Aaron Rodgers   9  2016-11-13  GNB  TEN  L 25-47
# 97  Aaron Rodgers  10  2008-11-16  GNB  CHI   W 37-3
# 98  Aaron Rodgers   5  2016-10-16  GNB  DAL  L 16-30
# 99  Aaron Rodgers  10  2014-11-16  GNB  PHI  W 53-20
#
# [100 rows x 6 columns]

# %%
total_gamelog['R'] = total_gamelog['Result'].apply(lambda x : x[0])

# %%
total_gamelog = total_gamelog[['Player', 'G#', 'Date', 'Team', 'Opp', 'R']]

# %%
player_stats = pd.DataFrame(columns=['Player', 'W', 'T', 'L', 'Win %'])

# %%
player_stats['Player'] = total_gamelog['Player'].unique()

# %%
player_stats[['L','W','T']] = player_stats['Player'].apply(lambda x : total_gamelog[total_gamelog['Player'] == x]['R'].value_counts())

# %%
player_stats
# Out:
#                 Player     W    T     L Win %
# 0          A.J. Feeley   2.0  NaN   8.0   NaN
# 1        A.J. McCarron   NaN  NaN   2.0   NaN
# 2         Aaron Brooks  10.0  NaN  32.0   NaN
# 3        Aaron Rodgers  46.0  1.0  50.0   NaN
# 4         Adrian Breen   NaN  NaN   1.0   NaN
# ..                 ...   ...  ...   ...   ...
# 596         Will Levis   1.0  NaN   6.0   NaN
# 597      Willie Totten   NaN  NaN   1.0   NaN
# 598  Zach Mettenberger   NaN  NaN   7.0   NaN
# 599        Zach Wilson   6.0  NaN  13.0   NaN
# 600    Zeke Bratkowski   1.0  NaN   2.0   NaN
#
# [601 rows x 5 columns]

# %%
player_stats[['W','T','L']] = player_stats[['W','T','L']].fillna(0)

# %%
player_stats['Total'] = sum([player_stats['W'], player_stats['T'], player_stats['L']])

# %%
player_stats['Win %'] = (player_stats['W'] + (player_stats['T']/2))/player_stats['Total']

# %%
player_stats['Win %'] = player_stats['Win %'].round(1)

# %%
player_stats[player_stats['Total'] >= 10]
# Out:
#                Player     W    T     L     Win %  Total
# 0         A.J. Feeley   2.0  0.0   8.0  0.200000   10.0
# 2        Aaron Brooks  10.0  0.0  32.0  0.238095   42.0
# 3       Aaron Rodgers  46.0  1.0  50.0  0.479381   97.0
# 6         Akili Smith   1.0  0.0  10.0  0.090909   11.0
# 7          Al Woodall   3.0  0.0   9.0  0.250000   12.0
# ..                ...   ...  ...   ...       ...    ...
# 588       Vince Young   8.0  0.0  13.0  0.380952   21.0
# 589  Vinny Testaverde  30.0  0.0  75.0  0.285714  105.0
# 591       Wade Wilson  12.0  0.0  24.0  0.333333   36.0
# 592       Warren Moon  40.0  0.0  50.0  0.444444   90.0
# 599       Zach Wilson   6.0  0.0  13.0  0.315789   19.0
#
# [291 rows x 6 columns]

# %%
player_stats.to_csv('numbers.csv')

# %%
pro_bowl_qbs = pd.DataFrame(ping_url('https://stathead.com/football/player-season-finder.cgi?request=1&match=player_season_combined&order_by=age&positions%5B%5D=qb&pro_bowls_type=Y'))

# %%
pro_bowl_qbs = pro_bowl_qbs[['Player', 'PB']]

# %%
pro_bowl_qbs
# Out:
#                Player  PB
# 0     Matt Hasselbeck   3
# 1      Peyton Manning  14
# 2           Dan Fouts   6
# 3         Bill Kenney   1
# 4        Tommy Kramer   1
# ..                ...  ..
# 173        Alex Smith   3
# 174  Matthew Stafford   2
# 175    Fran Tarkenton   9
# 176      Michael Vick   4
# 177    Jameis Winston   1
#
# [178 rows x 2 columns]

# %%
all_pro_qbs = pd.DataFrame(ping_url('https://stathead.com/football/player-season-finder.cgi?request=1&match=player_season_combined&order_by=age&year_min=1966&positions%5B%5D=qb&all_pros_first_team_type=Y'))[['Player', 'AP1']]

# %%
all_pro_qbs
# Out:
#                 Player  AP1
# 0        Aaron Rodgers    4
# 1          Steve Young    3
# 2   Randall Cunningham    1
# 3        Johnny Unitas    1
# 4         Earl Morrall    2
# 5           Bart Starr    1
# 6          John Brodie    1
# 7           Len Dawson    1
# 8          Brett Favre    3
# 9          Kurt Warner    2
# 10       Roman Gabriel    1
# 11           John Hadl    1
# 12           Jim Kelly    1
# 13      Fran Tarkenton    1
# 14     Daryle Lamonica    2
# 15          Brian Sipe    1
# 16         Ken Stabler    1
# 17       Joe Theismann    1
# 18           Tom Brady    3
# 19      Boomer Esiason    1
# 20         Joe Montana    3
# 21          Joe Namath    1
# 22           Matt Ryan    1
# 23        Ken Anderson    1
# 24      Terry Bradshaw    1
# 25          Drew Brees    1
# 26           Dan Fouts    2
# 27         Rich Gannon    2
# 28          Bob Griese    2
# 29          Bert Jones    1
# 30     Patrick Mahomes    2
# 31      Peyton Manning    7
# 32          Dan Marino    3
# 33          Cam Newton    1
# 34       Lamar Jackson    2

# %%
hof_qbs = pd.DataFrame(ping_url('https://stathead.com/football/player-season-finder.cgi?request=1&match=player_season_combined&order_by=age&positions%5B%5D=qb&is_hof=Y'))

# %%
hof_qbs['HoF'] = 'Y'

# %%
hof_qbs = hof_qbs[['Player', 'HoF']]

# %%
hof_qbs
# Out:
#                Player HoF
# 0         Sammy Baugh   Y
# 1      Charley Trippi   Y
# 2         Warren Moon   Y
# 3      Roger Staubach   Y
# 4         Kurt Warner   Y
# 5           Jim Kelly   Y
# 6      Paddy Driscoll   Y
# 7         Otto Graham   Y
# 8         Ken Stabler   Y
# 9      Bob Waterfield   Y
# 10        Sid Luckman   Y
# 11  Norm Van Brocklin   Y
# 12        Steve Young   Y
# 13        Troy Aikman   Y
# 14      George Blanda   Y
# 15         John Elway   Y
# 16    Sonny Jurgensen   Y
# 17        Bobby Layne   Y
# 18        Joe Montana   Y
# 19      Johnny Unitas   Y
# 20     Terry Bradshaw   Y
# 21         Len Dawson   Y
# 22        Brett Favre   Y
# 23          Dan Fouts   Y
# 24         Bob Griese   Y
# 25     Peyton Manning   Y
# 26         Dan Marino   Y
# 27         Joe Namath   Y
# 28         Bart Starr   Y
# 29        Y.A. Tittle   Y
# 30     Fran Tarkenton   Y

# %%
player_stats_nu = pd.read_csv('numbers.csv')[['Player', 'W', 'T', 'L', 'Win %', 'Total']]

# %%
player_stats_nu
# Out:
#                 Player     W    T     L     Win %  Total
# 0          A.J. Feeley   2.0  0.0   8.0  0.200000   10.0
# 1        A.J. McCarron   0.0  0.0   2.0  0.000000    2.0
# 2         Aaron Brooks  10.0  0.0  32.0  0.238095   42.0
# 3        Aaron Rodgers  46.0  1.0  50.0  0.479381   97.0
# 4         Adrian Breen   0.0  0.0   1.0  0.000000    1.0
# ..                 ...   ...  ...   ...       ...    ...
# 596         Will Levis   1.0  0.0   6.0  0.142857    7.0
# 597      Willie Totten   0.0  0.0   1.0  0.000000    1.0
# 598  Zach Mettenberger   0.0  0.0   7.0  0.000000    7.0
# 599        Zach Wilson   6.0  0.0  13.0  0.315789   19.0
# 600    Zeke Bratkowski   1.0  0.0   2.0  0.333333    3.0
#
# [601 rows x 6 columns]

# %%
player_stats_nu = player_stats_nu.merge(pro_bowl_qbs, left_on='Player', right_on='Player', how='left')
player_stats_nu = player_stats_nu.merge(all_pro_qbs, left_on='Player', right_on='Player', how='left')
player_stats_nu = player_stats_nu.merge(hof_qbs, left_on='Player', right_on='Player', how='left')

# %%
player_stats_nu[['HoF']] = player_stats_nu[['HoF']].fillna('N')
player_stats_nu[['PB', 'AP1']] = player_stats_nu[['PB', 'AP1']].fillna(0)

# %%
player_stats_nu.to_csv('numbers2.csv')

# %%
player_stats_nu
# Out:
#                 Player     W    T     L     Win %  Total    PB  AP1 HoF
# 0          A.J. Feeley   2.0  0.0   8.0  0.200000   10.0   0.0  0.0   N
# 1        A.J. McCarron   0.0  0.0   2.0  0.000000    2.0   0.0  0.0   N
# 2         Aaron Brooks  10.0  0.0  32.0  0.238095   42.0   0.0  0.0   N
# 3        Aaron Rodgers  46.0  1.0  50.0  0.479381   97.0  10.0  4.0   N
# 4         Adrian Breen   0.0  0.0   1.0  0.000000    1.0   0.0  0.0   N
# ..                 ...   ...  ...   ...       ...    ...   ...  ...  ..
# 596         Will Levis   1.0  0.0   6.0  0.142857    7.0   0.0  0.0   N
# 597      Willie Totten   0.0  0.0   1.0  0.000000    1.0   0.0  0.0   N
# 598  Zach Mettenberger   0.0  0.0   7.0  0.000000    7.0   0.0  0.0   N
# 599        Zach Wilson   6.0  0.0  13.0  0.315789   19.0   0.0  0.0   N
# 600    Zeke Bratkowski   1.0  0.0   2.0  0.333333    3.0   0.0  0.0   N
#
# [601 rows x 9 columns]

# %%
player_stats_nu[player_stats_nu['Total'] > 9]
# Out:
#                Player     W    T     L     Win %  Total    PB  AP1 HoF
# 0         A.J. Feeley   2.0  0.0   8.0  0.200000   10.0   0.0  0.0   N
# 2        Aaron Brooks  10.0  0.0  32.0  0.238095   42.0   0.0  0.0   N
# 3       Aaron Rodgers  46.0  1.0  50.0  0.479381   97.0  10.0  4.0   N
# 6         Akili Smith   1.0  0.0  10.0  0.090909   11.0   0.0  0.0   N
# 7          Al Woodall   3.0  0.0   9.0  0.250000   12.0   0.0  0.0   N
# ..                ...   ...  ...   ...       ...    ...   ...  ...  ..
# 588       Vince Young   8.0  0.0  13.0  0.380952   21.0   2.0  0.0   N
# 589  Vinny Testaverde  30.0  0.0  75.0  0.285714  105.0   2.0  0.0   N
# 591       Wade Wilson  12.0  0.0  24.0  0.333333   36.0   1.0  0.0   N
# 592       Warren Moon  40.0  0.0  50.0  0.444444   90.0   9.0  0.0   Y
# 599       Zach Wilson   6.0  0.0  13.0  0.315789   19.0   0.0  0.0   N
#
# [291 rows x 9 columns]

# %%
def assign_status(row):
    if row['HoF'] == 'Y':
        return 'HoF'
    elif row['AP1'] > 0:
        return 'All Pro'
    elif row['PB'] > 0:
        return 'Pro Bowler'
    else:
        return 'JAG'

# %%
player_stats_nu['Status'] = player_stats_nu.apply(assign_status, axis=1)

# %%
player_stats_nu[(player_stats_nu['Status'] != 'JAG') * (player_stats_nu['Total'] > 9)].sort_values(by='Win %', ascending=False)
# Out:
#                Player     W    T     L     Win %  Total   PB  AP1 HoF  \
# 73        Brock Purdy   9.0  0.0   3.0  0.750000   12.0  1.0  0.0   N
# 299       Joe Montana  43.0  0.0  21.0  0.671875   64.0  8.0  3.0   Y
# 177      Don Meredith   7.0  1.0   4.0  0.625000   12.0  3.0  0.0   N
# 249       Jalen Hurts  15.0  0.0   9.0  0.625000   24.0  2.0  0.0   N
# 434   Patrick Mahomes  25.0  0.0  16.0  0.609756   41.0  6.0  2.0   N
# ..                ...   ...  ...   ...       ...    ...  ...  ...  ..
# 263        Jeff Blake   8.0  0.0  36.0  0.181818   44.0  1.0  0.0   N
# 399  Matthew Stafford  16.0  0.0  80.0  0.166667   96.0  2.0  0.0   N
# 238         Jack Kemp   2.0  1.0  13.0  0.156250   16.0  7.0  0.0   N
# 166    Derek Anderson   2.0  0.0  18.0  0.100000   20.0  1.0  0.0   N
# 415   Mike Taliaferro   1.0  0.0  11.0  0.083333   12.0  1.0  0.0   N
#
#          Status
# 73   Pro Bowler
# 299         HoF
# 177  Pro Bowler
# 249  Pro Bowler
# 434     All Pro
# ..          ...
# 263  Pro Bowler
# 399  Pro Bowler
# 238  Pro Bowler
# 166  Pro Bowler
# 415  Pro Bowler
#
# [145 rows x 10 columns]

# %%
player_stats_nu[(player_stats_nu['AP1'] == 0) * (player_stats_nu['HoF'] == 'Y')]
# Out:
#               Player     W    T     L     Win %  Total   PB  AP1 HoF Status
# 220    George Blanda   1.0  0.0   2.0  0.333333    3.0  4.0  0.0   Y    HoF
# 308       John Elway  46.0  0.0  53.0  0.464646   99.0  9.0  0.0   Y    HoF
# 464   Roger Staubach  26.0  0.0  21.0  0.553191   47.0  6.0  0.0   Y    HoF
# 504  Sonny Jurgensen  11.0  1.0  28.0  0.287500   40.0  5.0  0.0   Y    HoF
# 575      Troy Aikman  30.0  0.0  45.0  0.400000   75.0  6.0  0.0   Y    HoF
# 592      Warren Moon  40.0  0.0  50.0  0.444444   90.0  9.0  0.0   Y    HoF

# %%
sns.histplot(data=player_stats_nu[player_stats_nu['Total'] > 9], x='Win %', hue='Status', multiple='stack')
# Out:
# <AxesSubplot:xlabel='Win %', ylabel='Count'>
